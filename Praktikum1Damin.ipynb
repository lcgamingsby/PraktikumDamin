# %% [markdown]
# <a href="https://colab.research.google.com/github/gitclaudio23/DataMning/blob/main/Praktikkum1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Baca file Excel dari Google Drive
file_path = '/content/drive/MyDrive/dataset.xls'
df = pd.read_excel(file_path)

# %%
# Cek jumlah data yang hilang (missing data) di setiap kolom
print(df.isnull().sum())
# Out:
# No                0
# Diagnosa          0
# Institusi         0
# Area_Kota         0
# Rumah_Sakit    1131
# Tipe           2750
# Total            25
# dtype: int64

# %%
# Mengisi data yang hilang di kolom 'rumah' dengan modus (nilai yang paling sering muncul)
df['rumah'].fillna(df['rumah'].mode()[0], inplace=True)

# Mengisi data yang hilang di kolom 'tipe' dengan modus (nilai yang paling sering muncul)
df['tipe'].fillna(df['tipe'].mode()[0], inplace=True)

# Mengisi data yang hilang di kolom 'biaya_berobat' dengan median (nilai tengah)
df['biaya_berobat'].fillna(df['biaya_berobat'].median(), inplace=True)

# Cek kembali jumlah data yang hilang setelah penanganan
print(df.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-32-1b8da2e256fe> in <cell line: 2>()
#       1 # Mengisi data yang hilang di kolom 'rumah' dengan modus (nilai yang paling sering muncul)
# ----> 2 df[df.columns[df.columns.str.strip() == 'rumah'][0]].fillna(df[df.columns[df.columns.str.strip() == 'rumah'][0]].mode()[0], inplace=True)
#       3
#       4 # Mengisi data yang hilang di kolom 'tipe' dengan modus (nilai yang paling sering muncul)
#       5 df['tipe'].fillna(df['tipe'].mode()[0], inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5387             # GH#44051 exclude bool, which would return a 2d ndarray
#    5388             key = com.cast_scalar_indexer(key)
# -> 5389             return getitem(key)
#    5390
#    5391         if isinstance(key, slice):
#
# ...

# %%
# Simpan dataset yang sudah dihandle ke Google Drive
output_file_path = '/content/drive/MyDrive/dataset.xlsx'
df.to_excel(output_file_path, index=False)

# %%
print(f"Dataset berhasil disimpan ke: {output_file_path}")
# Out:
# Dataset berhasil disimpan ke: /content/drive/MyDrive/dataset.xlsx

# %%
# Convert all string columns to lowercase
for column in df.select_dtypes(['object']):
  df[column] = df[column].str.lower()

# %%
# Create a new column for the range of biaya_berobat
def categorize_biaya(biaya):
  if biaya <= 250000:
    return '0-250.000'
  elif biaya <= 500000:
    return '250.000-500.000'
  elif biaya <= 750000:
    return '500.000-750.000'
  elif biaya <= 1000000:
    return '750.000-1.000.000'
  else:
    return '>1.000.000'

df['range_biaya_berobat'] = df['biaya_berobat'].apply(categorize_biaya)

# Print the updated DataFrame
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'biaya_berobat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-93349bf14770> in <cell line: 14>()
#      12     return '>1.000.000'
#      13
# ...

# %%
# Simpan dataset yang sudah dihandle ke Google Drive
output_file_path = '/content/drive/MyDrive/dataset_lowercase.xlsx'
df.to_excel(output_file_path, index=False)

print(f"Dataset berhasil disimpan ke: {output_file_path}")
# Out:
# Dataset berhasil disimpan ke: /content/drive/MyDrive/dataset_lowercase.xlsx

# %%
import pandas as pd

# %%
file_path = '/content/drive/MyDrive/dataset_lowercase.xlsx'
df = pd.read_excel(file_path)

# %%
df = pd.read_excel(r'/content/drive/MyDrive/dataset_lowercase.xlsx')
df.head()
# Out:
#                                                PT IP       Unnamed: 1  \
# 0  report detail realisasi biaya perawatan keseha...              NaN
# 1      periode 01-jan-2016 sampai dengan 19-mar-2024              NaN
# 2                                                 no         diagnosa
# 3                                                NaN  hiperkolesterol
# 4                                                NaN   hiperlipidemia
#
#      Unnamed: 2 Unnamed: 3    Unnamed: 4 Unnamed: 5     Unnamed: 6
# 0           NaN        NaN           NaN        NaN            NaN
# 1           NaN        NaN           NaN        NaN            NaN
# 2     institusi       area         rumah       tipe  biaya_berobat
# 3   rumah sakit    bandung  rs borromeus        NaN            NaN
# 4  laboratorium      garut           NaN        NaN            NaN

# %%
df.head(10)
# Out:
#                                                PT IP       Unnamed: 1  \
# 0  report detail realisasi biaya perawatan keseha...              NaN
# 1      periode 01-jan-2016 sampai dengan 19-mar-2024              NaN
# 2                                                 no         diagnosa
# 3                                                NaN  hiperkolesterol
# 4                                                NaN   hiperlipidemia
# 5                                                NaN   hiperlipidemia
# 6                                                NaN          vertigo
# 7                                                NaN         check up
# 8                                                NaN          vertigo
# 9                                                NaN      pemeriksaan
#
#      Unnamed: 2 Unnamed: 3                     Unnamed: 4 Unnamed: 5  \
# 0           NaN        NaN                            NaN        NaN
# ...

# %%
df.tail()
# Out:
#       PT IP                         Unnamed: 1   Unnamed: 2 Unnamed: 3  \
# 37759   NaN  periksa kandungan dan gatal kulit  rumah sakit   sukabumi
# 37760   NaN                               gigi  rumah sakit   sukabumi
# 37761   NaN  pemeriksaan kandungan - kehamilan  rumah sakit   sukabumi
# 37762   NaN                               gigi  rumah sakit   sukabumi
# 37763   NaN  pemeriksaan kandungan - kehamilan  rumah sakit   sukabumi
#
#        Unnamed: 4                Unnamed: 5 Unnamed: 6
# 37759  rs assyifa          spesialis obsgyn        NaN
# 37760  rs assyifa  spesialis gigi dan mulut        NaN
# 37761  rs assyifa          spesialis obsgyn        NaN
# 37762  rs assyifa  spesialis gigi dan mulut        NaN
# 37763  rs assyifa          spesialis obsgyn        NaN

# %%
df.dtypes
# Out:
# PT IP         object
# Unnamed: 1    object
# Unnamed: 2    object
# Unnamed: 3    object
# Unnamed: 4    object
# Unnamed: 5    object
# Unnamed: 6    object
# dtype: object

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Iterate through columns, and check data type before plotting
for column in df.columns:
  # Check if the column data type is numeric
  if pd.api.types.is_numeric_dtype(df[column]):
    plt.figure(figsize=(15, 6))
    plt.hist(df[column], bins=20)
    plt.title(f"Histogram of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.show()

# %%
for column in df.columns:
  # Check if the column is numeric and not the index
  if pd.api.types.is_numeric_dtype(df[column]) and column != df.index.name:
    plt.figure(figsize=(10, 6))
    # Convert index to numeric if it's not already
    x_values = pd.to_numeric(df.index, errors='coerce') # Convert to numeric, handle errors
    # Filter out NaN values after conversion
    mask = ~pd.isna(x_values) & ~pd.isna(df[column])
    plt.scatter(x_values[mask], df[column][mask])
    plt.title(f"Scatter Plot of {column}")
    plt.xlabel("Index")
    plt.ylabel(column)
    plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# Mengasumsikan dataset adalah df dan kolom 'diagnosa' adalah kategorik
dataolahencoding = df.copy() # Membuat salinan dataset untuk mencegah modifikasi dataset asli

# Label encoding untuk kolom 'diagnosa'
encoder = LabelEncoder()
dataolahencoding['diagnosa_encod'] = encoder.fit_transform(dataolahencoding['diagnosa'])
dataolahencoding['institusi_encod'] = encoder.fit_transform(dataolahencoding['institusi'])
dataolahencoding['area_encod'] = encoder.fit_transform(dataolahencoding['area'])
dataolahencoding['rumah_encod'] = encoder.fit_transform(dataolahencoding['rumah'])
dataolahencoding['tipe_encod'] = encoder.fit_transform(dataolahencoding['tipe'])
dataolahencoding['biaya_berobat_encod'] = encoder.fit_transform(dataolahencoding['biaya_berobat'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'diagnosa'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-74d943f25223> in <cell line: 8>()
#       6 # Label encoding untuk kolom 'diagnosa'
# ...

# %%
dataolahencoding.head()
# Out:
#                                                PT IP       Unnamed: 1  \
# 0  report detail realisasi biaya perawatan keseha...              NaN
# 1      periode 01-jan-2016 sampai dengan 19-mar-2024              NaN
# 2                                                 no         diagnosa
# 3                                                NaN  hiperkolesterol
# 4                                                NaN   hiperlipidemia
#
#      Unnamed: 2 Unnamed: 3    Unnamed: 4 Unnamed: 5     Unnamed: 6
# 0           NaN        NaN           NaN        NaN            NaN
# 1           NaN        NaN           NaN        NaN            NaN
# 2     institusi       area         rumah       tipe  biaya_berobat
# 3   rumah sakit    bandung  rs borromeus        NaN            NaN
# 4  laboratorium      garut           NaN        NaN            NaN

# %%
dataolahencoding = dataolahencoding.drop(['diagnosa', 'institusi', 'area', 'rumah', 'tipe', 'biaya_berobat'], axis=1)
dataolahencoding.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-f682ad470272> in <cell line: 1>()
# ----> 1 dataolahencoding = dataolahencoding.drop(['diagnosa', 'institusi', 'area', 'rumah', 'tipe', 'biaya_berobat'], axis=1)
#       2 dataolahencoding.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# ...

# %%
dataolahencoding['range_biaya_berobat_numeric'] = pd.to_numeric(dataolahencoding['range_biaya_berobat'].str.split('-').str[0], errors='coerce')

for column in dataolahencoding.columns:
  if pd.api.types.is_numeric_dtype(dataolahencoding[column]):  # Check if column is numeric
    plt.figure(figsize=(10, 6))
    plt.boxplot(dataolahencoding[column])
    plt.title(f"Box Plot of {column}")
    plt.ylabel(column)
    plt.show()
  else:
    print(f"Skipping box plot for non-numeric column: {column}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'range_biaya_berobat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-4745debc02cf> in <cell line: 1>()
# ...

# %%
import numpy as np

def find_outliers_iqr(data):
  Q1 = np.percentile(data, 25)
  Q3 = np.percentile(data, 75)
  IQR = Q3 - Q1
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR
  outliers = [x for x in data if x < lower_bound or x > upper_bound]
  return outliers

# Filter out non-numeric columns before applying outlier detection
numeric_columns = dataolahencoding.select_dtypes(include=np.number).columns

for column in numeric_columns:
  outliers = find_outliers_iqr(dataolahencoding[column])
  if outliers:
    print(f"Kolom '{column}' memiliki outlier:")
    print(outliers)
    print()
# Out:
# Kolom 'area_encod' memiliki outlier:
# ...

# %%
import seaborn as sns


# Assuming dataolahencoding is your DataFrame

# Replace non-numeric values with NaN and convert to numeric
dataolahencoding['range_biaya_berobat'] = pd.to_numeric(dataolahencoding['range_biaya_berobat'].str.replace('[^0-9.]', '', regex=True), errors='coerce')

# Calculate correlation matrix only on numeric columns
correlation_matrix = dataolahencoding.select_dtypes(include=np.number).corr()

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'range_biaya_berobat'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-a306d07e0379> in <cell line: 7>()
#       5
# ...

# %%
# prompt: add 5 more multivariate diagram for database above

import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'dataolahencoding' is your DataFrame

# 1. Pairplot
sns.pairplot(dataolahencoding[['diagnosa_encod', 'institusi_encod', 'area_encod', 'rumah_encod', 'range_biaya_berobat']])
plt.show()

# 2. Scatter Plot Matrix with Specific Columns
pd.plotting.scatter_matrix(dataolahencoding[['diagnosa_encod', 'institusi_encod', 'area_encod', 'rumah_encod', 'range_biaya_berobat']], figsize=(12, 12), diagonal='kde')
plt.show()

# 3. Jointplot (Relationship between two variables)
sns.jointplot(x='diagnosa_encod', y='range_biaya_berobat', data=dataolahencoding, kind='reg')
plt.show()

# 4. Violin Plot (Distribution of a variable based on another categorical variable)
sns.violinplot(x='institusi_encod', y='range_biaya_berobat', data=dataolahencoding)
plt.show()

# 5. Box Plot (Distribution of a variable based on another categorical variable)
sns.boxplot(x='area_encod', y='range_biaya_berobat', data=dataolahencoding)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-c5789bc086c8> in <cell line: 9>()
#       7
#       8 # 1. Pairplot
# ----> 9 sns.pairplot(dataolahencoding[['diagnosa_encod', 'institusi_encod', 'area_encod', 'rumah_encod', 'range_biaya_berobat']])
#      10 plt.show()
#      11
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# ...
